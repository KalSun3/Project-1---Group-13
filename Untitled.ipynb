# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the CSV file 
data1 = pd.read_csv("C:/users/lmpel/Project 1/Project-1---Group-13/Resources/ds_salaries.csv")
data1.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
# Small less than 50, medium 50 to 249, Large greater than 250 
company_size = data1["company_size"].value_counts()
size_labels = {'S': 'Small(<50)', 'M': 'Medium(50-249)', 'L' :'Large(>250)'}
company_size.index = company_size.index.map(size_labels)

# %%
# Make the pie chart
plt.figure(figsize=(10, 8))
plt.pie(company_size, labels=company_size.index,autopct= "%1.1F%%")
plt.title("Company size for Data Analysis jobs")
plt.legend(size_labels.values(), title='Company Size')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.boxplot([data1[data1['company_size'] == size]['salary_in_usd'] for size in data1['company_size'].unique()], labels=data1['company_size'].unique())
plt.title('Company Size vs Salary')
plt.xlabel('Company Size')
plt.ylabel('Salary in USD')
legend_labels = data1['company_size'].unique()
handles = [plt.Line2D([0], [0], marker='o', color='w', label=label, markerfacecolor='b', markersize=10) for label in legend_labels]
plt.legend(handles=handles, title='Company Size')
plt.show()

# %%
# Load the CSV file 
data2 = pd.read_csv("C:/users/lmpel/Project 1/Project-1---Group-13/Resources/career_projections.csv")
data2
# Out:
#                 2023 National Employment Matrix title  \
# 0                                 Management analysts
# 1         Compensation, benefits, and job analysis...
# 2         Market research analysts and marketing s...
# 3                                     Budget analysts
# 4                                     Credit analysts
# 5                   Financial and investment analysts
# 6                           Computer systems analysts
# 7                       Information security analysts
# 8           Software quality assurance analysts an...
# 9                        Operations research analysts
# 10          News analysts, reporters, and journalists
#
#    2023 National Employment Matrix code Occupation type Employment, 2023  \
# 0                               13-1111       Line item          1,018.3
# 1                               13-1141       Line item            103.7
# 2                               13-1161       Line item            903.4
# 3                               13-2031       Line item             50.8
# 4                               13-2041       Line item             73.7
# 5                               13-2051       Line item            347.4
# 6                               15-1211       Line item            527.2
# 7                               15-1212       Line item            180.7
# 8                               15-1253       Line item            205.0
# 9                               15-2031       Line item            123.3
# 10                              27-3023       Line item             49.8
#
#    Employment, 2033  Employment change, numeric, 2023–33  \
# 0           1,126.2                                107.9
# 1             111.0                                  7.2
# 2             978.3                                 74.9
# 3              52.7                                  2.0
# 4              70.8                                 -2.8
# 5             380.5                                 33.1
# 6             583.7                                 56.5
# 7             239.8                                 59.1
# 8             229.2                                 24.2
# 9             151.6                                 28.3
# 10             48.4                                 -1.4
#
#     Employment change, percent, 2023–33  \
# 0                                  10.6
# 1                                   7.0
# 2                                   8.3
# 3                                   3.9
# 4                                  -3.9
# 5                                   9.5
# 6                                  10.7
# 7                                  32.7
# 8                                  11.8
# 9                                  23.0
# 10                                 -2.7
#
#     Labor force exit rate, 2023–33 annual average  \
# 0                                             3.1
# 1                                             2.7
# 2                                             2.6
# 3                                             2.3
# 4                                             1.8
# 5                                             1.9
# 6                                             2.5
# 7                                             1.7
# 8                                             2.4
# 9                                             3.2
# 10                                            4.1
#
#     Occupational transfer rate, 2023–33 annual average  \
# 0                                                 4.8
# 1                                                 4.3
# 2                                                 6.0
# 3                                                 3.9
# 4                                                 5.0
# 5                                                 4.3
# 6                                                 3.2
# 7                                                 3.7
# 8                                                 3.4
# 9                                                 3.0
# 10                                                5.4
#
#     Total occupational separations rate, 2023–33 annual average  \
# 0                                                 7.9
# 1                                                 7.0
# 2                                                 8.6
# 3                                                 6.2
# 4                                                 6.8
# 5                                                 6.2
# 6                                                 5.7
# 7                                                 5.4
# 8                                                 5.8
# 9                                                 6.2
# 10                                                9.5
#
#     Labor force exits, 2023–33 annual average  \
# 0                                        33.3
# 1                                         2.9
# 2                                        24.7
# 3                                         1.2
# 4                                         1.3
# 5                                         6.9
# 6                                        14.0
# 7                                         3.6
# 8                                         5.2
# 9                                         4.4
# 10                                        2.0
#
#     Occupational transfers, 2023–33 annual average  \
# 0                                             51.6
# 1                                              4.6
# 2                                             56.3
# 3                                              2.0
# 4                                              3.6
# 5                                             15.8
# 6                                             17.7
# 7                                              7.8
# 8                                              7.4
# 9                                              4.1
# 10                                             2.7
#
#     Total occupational separations, 2023–33 annual average  \
# 0                                                84.9
# 1                                                 7.5
# 2                                                81.0
# 3                                                 3.2
# 4                                                 4.9
# 5                                                22.7
# 6                                                31.7
# 7                                                11.4
# 8                                                12.6
# 9                                                 8.5
# 10                                                4.7
#
#     Occupational openings, 2023–33 annual average
# 0                                            95.7
# 1                                             8.2
# 2                                            88.5
# 3                                             3.4
# 4                                             4.6
# 5                                            26.1
# 6                                            37.3
# 7                                            17.3
# 8                                            15.0
# 9                                            11.3
# 10                                            4.5

# %%
#Create DataFrame
data_frame = pd.DataFrame(data2, columns=['2023 National Employment Matrix title', 'Employment, 2023', 'Employment, 2033'])
data_sorted = data_frame.sort_values(by='Employment, 2023', ascending=False)
data_sorted.set_index('2023 National Employment Matrix title')
employment = data_sorted.head(11)
employment
# Out:
#                 2023 National Employment Matrix title Employment, 2023  \
# 2         Market research analysts and marketing s...            903.4
# 4                                     Credit analysts             73.7
# 6                           Computer systems analysts            527.2
# 3                                     Budget analysts             50.8
# 10          News analysts, reporters, and journalists             49.8
# 5                   Financial and investment analysts            347.4
# 8           Software quality assurance analysts an...            205.0
# 7                       Information security analysts            180.7
# 9                        Operations research analysts            123.3
# 1         Compensation, benefits, and job analysis...            103.7
# 0                                 Management analysts          1,018.3
#
#    Employment, 2033
# 2             978.3
# 4              70.8
# 6             583.7
# 3              52.7
# 10             48.4
# 5             380.5
# 8             229.2
# 7             239.8
# 9             151.6
# 1             111.0
# 0           1,126.2

# %%
job_titles = employment['2023 National Employment Matrix title']
employment_2023 = employment['Employment, 2023']
employment_2033 = employment['Employment, 2033']
employment_2033
# Out:
# 2       978.3
# 4        70.8
# 6       583.7
# 3        52.7
# 10       48.4
# 5       380.5
# 8       229.2
# 7       239.8
# 9       151.6
# 1       111.0
# 0     1,126.2
# Name: Employment, 2033, dtype: object

# %%
# Sort the data based on employment values in descending order
sorted_indices = np.argsort(employment_2023)[::-1]
job_titles_sorted = [job_titles[i] for i in sorted_indices]
employment_2023_sorted = [employment_2023[i] for i in sorted_indices]
employment_2033_sorted = [employment_2033[i] for i in sorted_indices]

plt.figure(figsize=(12, 8))

bar_width = 0.35  # Width of each bar
index = np.arange(len(job_titles_sorted))  # Index for the job titles

# Plot the bars for 2023 employment
plt.barh(index - bar_width/2, employment_2023_sorted, bar_width, color='green', label='2023')

# Plot the bars for 2033 employment
plt.barh(index + bar_width/2, employment_2033_sorted, bar_width, color='blue', label='2033')

plt.xlabel("Employment, USD Thousand")
plt.ylabel("Job Titles")
plt.title("Ten Year Employment Projections 2023-2033")
plt.yticks(index, job_titles_sorted)  # Set the y-ticks to display job titles in descending order
plt.legend()  # Add a legend to differentiate between the years

plt.show()

# %%
plt.figure(figsize=(12, 8))
bar_width = 0.35
index = np.arange(len(job_titles))
plt.barh(index - bar_width/2, employment_2023, bar_width, color='green', label='2023')
plt.barh(index + bar_width/2, employment_2033, bar_width, color='blue', label='2033')
plt.xlabel("Employment, Thousand")
plt.ylabel("Job Titles")
plt.yticks(index, job_titles)
plt.title("Ten Year Employment Projections 2023-2033")
plt.show()

# %%
y=['2023 National Employment Matrix title']
x=['Employment, 2023']
plt.barh(y,x)
plt.ylabel("Job Titles")
plt.xlabel("Employment, Thousand")
plt.title("Ten Year Employment Projections 2023-2033")
plt.show()

# %%
#Define Variables
bar_one = employment['Employment, 2023']
bar_one_label = '2023 Employment, USD Thousand'
bar_one_color = 'red'
bar_two = employment['Employment, 2033']
bar_two_label = '2033 Employment, USD Thousand'
bar_two_color = 'blue'
labels = employment.index
width = 0.5
plot_title = 'Ten Year Employment Projections 2023-2033'
title_size = 18
subtitle = 'Source: Employment Projections program, U.S. Bureau of Labor Statistics'

# %%
#Additional Graph Properties
employment.sort_values(by='Employment, 2023', inplace=True, ascending=True)
fig, ax = plt.subplots(figsize=(10,6))
plt.tight_layout()

# %%
#Plot double bars
y = np.arrange(len(labels))
ax.barh(y + width/2, bar_one, width, label=bar_one_label, color=bar_one_color)
ax.barh(y - width/2, bar_two, width, label=bar_two_label, color=bar_two_color)
#Format ticks
ax.xasis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

# %%
#
